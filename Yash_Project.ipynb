# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'/content/Lending-Company-Saving (1).csv')
df
# Out:
#       LoanID StringID    Product CustomerGender      Location    Region  \
# 0          1     id_1  Product B           Male    Location 2  Region 2
# 1          2     id_2  Product B           Male    Location 3       NaN
# 2          3     id_3  Product C         Female    Location 5  Region 5
# 3          4     id_4  Product B           Male    Location 6  Region 1
# 4          5     id_5  Product D         Female    Location 7  Region 2
# ...      ...      ...        ...            ...           ...       ...
# 1038    1039  id_1039  Product B         Female   Location 39  Region 6
# 1039    1040  id_1040  Product B           Male   Location 50  Region 1
# 1040    1041  id_1041  Product B           Male   Location 23  Region 4
# 1041    1042  id_1042  Product C   NotSpecified   Location 52  Region 6
# 1042    1043  id_1043  Product B         Female  Location 142  Region 6
#
#       TotalPrice
# 0        16600.0
# 1        16600.0
# 2        15600.0
# 3        16600.0
# ...

# %%
# Basic Information
# Names of columns
df.columns
# Out:
# Index(['LoanID', 'StringID', 'Product', 'CustomerGender', 'Location', 'Region',
#        'TotalPrice'],
#       dtype='object')

# %%
# first five row
df.head()
# Out:
#    LoanID StringID    Product CustomerGender    Location    Region  TotalPrice
# 0       1     id_1  Product B           Male  Location 2  Region 2     16600.0
# 1       2     id_2  Product B           Male  Location 3       NaN     16600.0
# 2       3     id_3  Product C         Female  Location 5  Region 5     15600.0
# 3       4     id_4  Product B           Male  Location 6  Region 1     16600.0
# 4       5     id_5  Product D         Female  Location 7  Region 2     20250.0

# %%
#last five rows
df.tail()
# Out:
#       LoanID StringID    Product CustomerGender      Location    Region  \
# 1038    1039  id_1039  Product B         Female   Location 39  Region 6
# 1039    1040  id_1040  Product B           Male   Location 50  Region 1
# 1040    1041  id_1041  Product B           Male   Location 23  Region 4
# 1041    1042  id_1042  Product C   NotSpecified   Location 52  Region 6
# 1042    1043  id_1043  Product B         Female  Location 142  Region 6
#
#       TotalPrice
# 1038     16600.0
# 1039         NaN
# 1040     16600.0
# 1041     15600.0
# 1042     16600.0

# %%
# Number of rows and columns
df.shape
# Out:
# (1043, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1043 entries, 0 to 1042
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   LoanID          1043 non-null   int64
#  1   StringID        1043 non-null   object
#  2   Product         1043 non-null   object
#  3   CustomerGender  1043 non-null   object
#  4   Location        1043 non-null   object
#  5   Region          1042 non-null   object
#  6   TotalPrice      1019 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 57.2+ KB

# %%
# Statistical summary
df.describe()
# Out:
#             LoanID    TotalPrice
# count  1043.000000   1019.000000
# mean    522.000000  19082.801766
# std     301.232468   5904.339063
# min       1.000000  13775.000000
# 25%     261.500000  16600.000000
# 50%     522.000000  16600.000000
# 75%     782.500000  20250.000000
# max    1043.000000  69225.000000

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Missing values
df.isnull().sum()
# Out:
# LoanID             0
# StringID           0
# Product            0
# CustomerGender     0
# Location           0
# Region             1
# TotalPrice        24
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
#boxplot
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['TotalPrice'])
plt.title('Boxplot of Total Price')
plt.xlabel('Total Price')
plt.show()

# %%
#bar graph
plt.figure(figsize=(6, 4))
df['Product'].value_counts().plot(kind='bar', color='lightgreen')
plt.title('Number of Loans per Product')
plt.xlabel('Product')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
#scatter plot
plt.figure(figsize=(6, 4))
sns.stripplot(x='Region', y='TotalPrice', data=df, jitter=True)
plt.title('Total Price Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Total Price')
plt.xticks(rotation=45)
plt.show()

# %%
#pie chart
plt.figure(figsize=(6, 6))
df['CustomerGender'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Customer Gender Distribution')
plt.ylabel('')
plt.show()
